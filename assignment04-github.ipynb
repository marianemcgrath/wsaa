# %% [markdown]
# # GitHub Replacements
#
# **Author: Mariane McGrath**

# %% [markdown]
# A program in python that will read a file from a repository. The program replaces all the instances of the text "Andrew" with "Mariane".
#
# The program should then commit those changes and push the file back to the repository (You will need authorisation to do this).
#
# *API Keys must be hidden*

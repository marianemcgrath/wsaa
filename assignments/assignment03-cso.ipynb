# %% [markdown]
# # Assignment 03 - CSO
#
# **Author: Mariane McGrath**
#
# A program that **retrieves the dataset for the "exchequer account (historical series)" from the CSO,
# and stores it into a file called "cso.json"**

# %%
# Import required libraries
import requests
import json

# %%
# Define the URL
url = "https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/FIQ02/JSON-stat/2.0/en"

# Make a GET request to the URL
cso_response = requests.get(url)
cso_response.raise_for_status()

data = cso_response.json()

# %%
if cso_response.status_code == 200:
    with open('cso.json', 'w') as file:
        file.write(cso_response.text)
else:
    print(f'Unable to fetch details from CSO: {cso_response.status_code}')

# Source: https://stackoverflow.com/questions/62418874/using-json-files-to-store-and-retrieve-list-data

# %% [markdown]
# # GitHub Replacements
#
# **Author: Mariane McGrath**

# %% [markdown]
# A program in python that will read a file from a repository.
#
# The program replaces all the instances of the text "Andrew" with "Mariane".
#
# The program should then commit those changes and push the file back to the repository.
#
# *API Keys must be hidden*

# %% [markdown]
# 📝  STEP 1 — Creating file in repository
#
#     ✅  File created at: assignment/names.txt

# %%
# Create file in repository
with open('new_file.txt', 'w') as file:
    file.write('This is a new file created in the repository.\n')
print('File "new_file.txt" has been created in the repository.')
# Out:
# File "new_file.txt" has been created in the repository.
